# %% [markdown]
# <a href="https://colab.research.google.com/github/mercykdiazv/sistemas-avanzados-de-produccion/blob/main/aguirre_fabian_leon_daniel_garcia_jonathan_diaz_mercy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![logo-ECCI.png](data:image/png;base64,...)
# # **SISTEMAS AVANZADOS DE PRODUCCIÓN CON PYTHON**
#
# # **Clase 1 (2h): Introducción a Jupyter/Colab y al entorno de análisis de datos en Python**
#
# **Objetivos de la sesión**
# - Configurar y usar Google Colab como entorno de trabajo.
# - Comprender la estructura de un notebook (celdas de código y Markdown) y buenas prácticas.
# - Importar y verificar librerías clave para análisis de datos: `numpy`, `pandas`, `matplotlib`, `seaborn`, `statsmodels`.
# - Cargar un `.csv` y realizar una exploración inicial.
# - Practicar *slicing* (filas/columnas) y conteo de valores faltantes.

# %% [markdown]
# ## <strong>Guía Rápida: Markdown y Google Colaboratory</strong>

# %% [markdown]
# ###**¿Qué es Markdown?**
#
# Markdown es un lenguaje de marcado ligero que te permite dar formato a texto de manera sencilla y legible. En lugar de usar botones complejos como en un editor de texto tradicional (por ejemplo, Microsoft Word), escribes con símbolos simples para crear encabezados, listas, texto en negrita o cursiva, y mucho más.
#
# La idea principal es que el texto que escribes sea fácil de leer por sí solo, pero que también se pueda convertir fácilmente a HTML para verse bien en una página web o, como en este caso, en un notebook de Colab.
#
# 🎬 Tutorial rápido de Markdown (página): https://markdown.es/

# %% [markdown]
# ###**¿Qué es Google Colaboratory?**
#
# Google Colaboratory (o "Colab") es un entorno interactivo que se ejecuta en la nube de Google. Piensa en él como un cuaderno digital 📓 que te permite combinar:
#
# Texto enriquecido: Como esta misma celda, con formato, imágenes y enlaces.
#
# Código ejecutable: Principalmente Python, con acceso a librerías populares para ciencia de datos como Pandas, NumPy y Scikit-learn.
#
# Resultados del código: Gráficos, tablas y salidas de tus programas.
#
# Lo mejor de todo es que es gratuito y no requiere ninguna configuración en tu computadora. Además, te da acceso a hardware potente (GPUs y TPUs) que es ideal para proyectos de Machine Learning. Es una herramienta perfecta para aprender, enseñar y colaborar.
#
# 🚀 Primeros pasos con Google Colab (lectura): Guía de introducción a Colaboratory (Google)

# %% [markdown]
# ## <strong>Flujo de trabajo recomendado (Colab ⇄ Drive\Local\Github)</strong>
#
# <p align="center">
#   <img src="data:image/png;base64,..." alt="Total.png" width="400">
# </p>
#
#
# 1. Abre este notebook en **Google Colab**.
# 2. Guarda una copia en tu drive, pc o repositorio: `Archivo → Guardar una copia en GitHub`.
# 3. Versiona tu trabajo repitiendo el guardado al final de la clase.

# %% [markdown]
# ### **Conectando Colab con tus Archivos y Repositorios**
#
# Para un flujo de trabajo eficiente, es fundamental conectar tu notebook de Colab con tus archivos en Google Drive, tu repositorio en GitHub o en tu pc local.

# %% [markdown]
# #### **1. Conectar con Google Drive y trabajar con Archivos desde Drive**
#
#
#
#
# <p align="center">
#   <img src="data:image/jpeg;base64,..." alt="Google-Drive.png" width="400">
# </p>
#
#
# Montar tu Google Drive te da acceso a los archivos (datasets, imágenes, etc.) que tienes almacenados allí, directamente desde tu notebook.
#
# Paso 1: Ejecuta la siguiente celda de código.
#
# Paso 2: Haz clic en el enlace que aparece, autoriza el acceso con tu cuenta de Google.

# %%
# Haz clic en la flecha que está a la izquierda de la celda o usa el atajo Ctrl + Enter para ejecutar la celda.
# Esto es un comentario. No afecta al programa.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### **2.  Trabajar con Archivos de tu PC Local 💻**
#
#
#
#
# <p align="center">
#   <img src="data:image/jpeg;base64,..." alt="colab-local.png" width="400">
# </p>
#
# Puedes subir archivos directamente desde tu computadora para usarlos en tu sesión actual. Ten en cuenta que estos archivos son temporales y se borrarán cuando el entorno de ejecución se reinicie.
#
# Método 1
#
# Paso 1: En el panel izquierdo, haz clic en el ícono de la carpeta 📁 para abrir el explorador de archivos.
#
# Paso 2: Haz clic en el ícono de "Subir archivo" (una hoja con una flecha hacia arriba).
#
# Paso 3: Selecciona el archivo que deseas subir desde tu PC. Una vez cargado, puedes usarlo en tu código referenciando su ruta (por ejemplo, /content/mi_archivo.csv).
#
#
# Método 2
#
# Ejecuta la siguiente celda de código

# %%
# Para detener la ejecución de la celda, vuelve a hacer clic en el ícono de flecha o presiona Ctrl + M I (no es necesario usar mayúsculas).
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f76f4de7-f872-4a08-b3a9-2b31e760f807" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f76f4de7-f872-4a08-b3a9-2b31e760f807">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ####**3. Conectar con Github**
#
# ¿Qué es GitHub? 🐙
# Imagina que GitHub es como un Google Drive, pero especializado para guardar código y proyectos. Es una plataforma en internet que te permite:
#
# *   Guardar tu trabajo en la nube: Tus notebooks de Colab estarán seguros y accesibles desde cualquier lugar.
# *   Tener un historial de cambios: GitHub guarda cada versión de tu trabajo. Si algo sale mal, puedes "viajar en el tiempo" a una versión anterior que sí funcionaba.
# *   Compartir tu código: Permite que otros vean tu trabajo de forma ordenada y profesional.
#
#
#
# ![Github-Colab.png](data:image/png;base64,...)
#
#
# **Paso 1: Crear tu Cuenta de GitHub ✍️**
# Crear una cuenta es gratis. Al usar tu correo institucional, puedes acceder a beneficios adicionales para estudiantes.
#
# *   Ve a la página de registro de GitHub: https://github.com/login
#
# *   Introduce tu correo electrónico @ecci.edu.co.
#
# *   Crea una contraseña segura.
#
# *   Elige un nombre de usuario. Te recomendamos que sea profesional (ej. nombreapellido o n-apellido), ya que podrías usarlo en tu futuro portafolio.
#
# *   Completa la verificación y haz clic en "Crear cuenta". Recibirás un correo para verificar tu dirección de email.
#
# Dato extra: Con tu correo @ecci.edu.co, puedes solicitar el GitHub Student Developer Pack, que te da acceso gratuito a muchas herramientas profesionales.
#
# **Paso 2: Crear tu Primer Repositorio 📂**
# Un "repositorio" es simplemente una carpeta en la nube para un proyecto específico. Por ejemplo, tendrás un repositorio para este curso.
#
# *   Una vez en tu cuenta, busca el botón "New" (Nuevo) o un símbolo de "+" en la esquina superior derecha y selecciona "New repository".
#
# *   Dale un nombre a tu repositorio. Por ejemplo: curso-ciencia-de-datos.
#
# *   Añade una descripción breve (opcional).
#
# *   Asegúrate de que esté marcado como "Public" (Público) para que otros puedan verlo si compartes el enlace.
#
# *   ¡Importante! Marca la casilla que dice "Add a README file". Esto prepara tu repositorio para que puedas guardar archivos en él.
#
# *   Haz clic en el botón verde "Create repository".
#
# ¡Listo! Ya tienes tu primera carpeta de proyecto en GitHub.
#
# **Paso 3: Conectar Colab y Guardar tu Notebook por Primera Vez 🔗**
# Ahora vamos a guardar el notebook de la clase en el repositorio que acabas de crear.
#
# *   En tu notebook de Google Colab, ve al menú Archivo en la esquina superior izquierda.
#
# *   Selecciona Guardar una copia en GitHub.
#
# *   Aparecerá una ventana pidiéndote autorizar a Google Colab para que acceda a tu GitHub. Dale permiso. Es un paso seguro y necesario que solo harás una vez.
#
# En la siguiente ventana, elige:
#
# *   Repositorio: Busca y selecciona el repositorio que creaste (ej. curso-ciencia-de-datos).
#
# *   Mensaje de commit: Escribe un comentario corto que describa este guardado. Como es la primera vez, algo como "Primera versión del notebook de la clase 1" es perfecto.
#
# *   Haz clic en "Aceptar".
#
# Tu notebook ahora está guardado de forma segura en tu repositorio de GitHub.
#
# **Paso 4: Actualizar tu Trabajo (Guardar Cambios en el Mismo Archivo) 🔄**
# Supongamos que sigues trabajando en tu notebook y haces más cambios. Para actualizarlos en el mismo archivo de GitHub, el proceso es muy similar.
#
# *   Vuelve a ir a Archivo → Guardar una copia en GitHub.
#
# *   Colab detectará que este archivo ya existe en tu repositorio, por lo que no creará uno nuevo, sino que actualizará el existente.
#
# *   En el campo "Mensaje de commit", describe los nuevos cambios que hiciste. Por ejemplo: "Añadido el análisis de datos exploratorio" o "Corregidos los errores en la gráfica".
#
# *   Haz clic en "Aceptar".
#
# Hacer esto guarda una nueva "foto" del estado de tu proyecto, y el mensaje de commit ayuda a recordar qué hiciste en cada paso.
#
#
#
# ***Concepto Clave: ¿Qué es una "Rama"? 🌳***
#
# *De forma muy sencilla, una rama es como crear una copia temporal de tu proyecto para experimentar.*
#
# *Imagina que tu proyecto principal es un documento de Word (rama principal o main). Si quieres probar un cambio grande pero no estás seguro si funcionará, en lugar de arriesgar el original, le sacas una copia. En esa copia (rama nueva) haces todos los experimentos que quieras. Si funcionan, luego los unes al documento original.*
#
# *Para este curso, no te preocupes por esto. Siempre trabajarás en la rama por defecto, que se llama main. Simplemente es bueno saber que esta funcionalidad existe para trabajos en equipo más complejos.*

# %% [markdown]
# ## **Primeros Pasos en Python 🐍**
# Python es un lenguaje de programación conocido por su simplicidad y legibilidad. Es ideal para principiantes y muy potente para aplicaciones de ciencia de datos. Vamos a explorar los conceptos básicos.
#
# Comentarios
# En Python, cualquier línea que comience con el símbolo # es un comentario. El código en estas líneas no se ejecuta; los comentarios sirven para dejar notas y explicar lo que hace tu código, tanto para ti en el futuro como para otras personas que lo lean.

# %%
print('Hola, Notebook 👋')
1 + 2

# %%
print(1 + 2)
1 + 3

# %%
1 + 2
1 + 3;  # suprime la última salida

# %% [markdown]
# ###**Operaciones Aritméticas Básicas**
#
# Puedes usar una celda de código de Colab como una calculadora para realizar operaciones matemáticas.

# %%
# Suma
5 + 3

# Resta
10 - 4

# Multiplicación
7 * 6

# División
8 / 2

# %% [markdown]
# ### **Variables: Guardando Información**
# Una variable es como una caja con una etiqueta donde guardamos un dato para usarlo más tarde. Para crear una, le das un nombre, usas el signo igual (=) y le asignas un valor.
#
# Los tipos de datos más comunes son:
#
# Números enteros (int): 5, -10, 100
#
# Números decimales (float): 3.14, -0.5
#
# Texto (string o str): Se escribe entre comillas, como 'Hola' o "Mundo".

# %%
# Creamos una variable llamada 'saludo' para guardar texto.
saludo = 'Hola, Python!'

# Creamos dos variables numéricas.
numero_a = 10
numero_b = 25

# Ahora podemos usar las variables para hacer operaciones.
suma_total = numero_a + numero_b

# %% [markdown]
# ### **Tipos de Variables y sus Reglas**
# En Python, cada variable tiene un "tipo" que define qué clase de dato es y qué puedes hacer con él.
#
# Los tipos de datos más básicos son:
#
#
#
#
# *    Texto (str) 🔡: Cualquier dato entre comillas (' ' o " "). Se usa para nombres, frases, etc.
#
# *   Entero (int) 🔢: Números enteros, sin decimales. Se usa para contar cosas.
#
# *   Decimal (float) 💧: Números con punto decimal. Se usa para medidas precisas como altura o precios.
#
# La regla principal es simple: puedes hacer operaciones matemáticas entre números, y puedes "sumar" textos para unirlos, pero no puedes mezclar operaciones matemáticas entre números y textos.

# %%
# --- Definición de Variables ---
# Una variable de texto (string)
nombre_estudiante = "Ana"

# Una variable numérica entera (int)
edad = 21

# Una variable numérica decimal (float)
altura_metros = 1.65

# --- ✅ Lo que SÍ se puede hacer ---

# 1. Operar entre tipos numéricos (int y float)
# Por ejemplo, calcular un índice simple (esto es solo un ejemplo)
indice_edad_altura = edad / altura_metros
print("El índice calculado es:", indice_edad_altura)

# 2. "Sumar" (concatenar) textos para unirlos
saludo_completo = "Hola, mi nombre es " + nombre_estudiante
print(saludo_completo)


# --- ❌ Lo que NO se puede hacer ---

# 3. Intentar sumar un número y un texto.
# La siguiente línea está comentada porque si la ejecutas, dará un error (TypeError).
# Descoméntala para ver el error y vuelve a comentarla.
# print("Mi edad es: " + edad)
# Out:
# El índice calculado es: 12.727272727272728
# Hola, mi nombre es Ana

# %% [markdown]
# ## **Buenas prácticas y lógica básica muy básica de programación**
#
# Indentación: 4 espacios para anidar bloques.
#
# Comentarios: Explican el "por qué" de una decisión, no el "qué" hace el código.
#
# Longitud: Líneas de código menores a 100 caracteres para fácil lectura.
#
# Bloques lógicos: Agrupar código que cumple una función específica.
#
# ## **Explicación del Código de Ejemplo**
#
# Este código es un ejemplo de bloques lógicos anidados que funcionan como un filtro.
#
# El objetivo es crear una lista (resultado) solo con las parejas de números (x, y) que cumplan una condición específica.
#
# Para lograrlo, el código revisa sistemáticamente todas las combinaciones posibles: primero toma un número x (del 0 al 9) y luego, para ese x, lo combina con cada número y (del 0 al 4).
#
# A cada pareja le aplica una regla: si la multiplicación x * y es mayor o igual a 10, la pareja pasa el filtro y se guarda en la lista final. Al final, se imprime la lista con todas las parejas que cumplieron la condición.

# %%
resultado = []
for x in range(10):
    for y in range(5):
        if x * y >= 10:
            resultado.append((x, y))
print(resultado)
# Out:
# [(3, 4), (4, 3), (4, 4), (5, 2), (5, 3), (5, 4), (6, 2), (6, 3), (6, 4), (7, 2), (7, 3), (7, 4), (8, 2), (8, 3), (8, 4), (9, 2), (9, 3), (9, 4)]

# %% [markdown]
# ## **Librerías Clave para Ciencia de Datos 📚**
#
#
# ¿Qué es una Librería y Para Qué Sirve?
# Imagina que estás construyendo algo. En lugar de fabricar tus propias herramientas desde cero (como un martillo o un destornillador), vas a una ferretería y compras una caja de herramientas ya hecha por expertos.
#
# En programación, una librería es exactamente eso: una caja de herramientas digital. Es un conjunto de código pre-escrito por otros programadores que nos da herramientas listas para usar, ahorrándonos tiempo y esfuerzo.
#
# ¿Para qué sirven? Para realizar tareas complejas (como crear gráficos o analizar tablas de datos) con comandos muy simples.
#
# ¿Cuándo se utilizan? Siempre que necesites una funcionalidad específica. Si vas a trabajar con tablas, usas la librería para tablas. Si vas a hacer gráficos, usas la librería para gráficos.

# %% [markdown]
# ### **NumPy 🔢**
# <p align="center">
# <img src="https://numpy.org/images/logo.svg" alt="Logo de NumPy" width="200">
# </p>
#
# Es la caja de herramientas para matemáticas y operaciones con números. Su fuerte es trabajar con grandes listas de números (llamadas arrays) de manera súper eficiente. Es la base de casi todo en ciencia de datos.
#
# Página oficial: https://numpy.org

# %%
import numpy as np

# Crear una lista de temperaturas en Celsius
temperaturas_celsius = np.array([0, 10, 20, 25, 30])

# NumPy permite aplicar una operación a toda la lista a la vez
temperaturas_fahrenheit = temperaturas_celsius * 9/5 + 32

print("Temperaturas en Fahrenheit:", temperaturas_fahrenheit)
# Out:
# Temperaturas en Fahrenheit: [32. 50. 68. 77. 86.]

# %% [markdown]
# ### **Pandas 🐼**
# <p align="center">
# <img src="https://pandas.pydata.org/static/img/pandas.svg" alt="Logo de Pandas" width="200">
# </p>
#
# Es como tener Excel dentro de Python. Nos da una herramienta llamada DataFrame, que es una tabla para organizar, limpiar, filtrar y analizar datos de manera muy intuitiva. Es la librería principal para la manipulación de datos.
#
# Página oficial: https://pandas.pydata.org

# %%
import pandas as pd

# Crear datos de producción
datos = {
    'Producto': ['Tornillo A', 'Tuerca B', 'Tornillo A'],
    'Cantidad': [150, 200, 120],
    'Calidad': ['Aceptable', 'Aceptable', 'Defectuoso']
}
df_produccion = pd.DataFrame(datos)

# Filtrar para ver solo los productos defectuosos
print(df_produccion[df_produccion['Calidad'] == 'Defectuoso'])
# Out:
#      Producto  Cantidad     Calidad
# 2  Tornillo A       120  Defectuoso

# %% [markdown]
# ### **Matplotlib 📊**
# <p align="center">
# <img src="https://matplotlib.org/stable/_static/logo_light.svg" alt="Logo de Matplotlib" width="200">
# </p>
#
# Es la caja de herramientas fundamental para crear gráficos. Te permite hacer todo tipo de visualizaciones (líneas, barras, histogramas, etc.) para entender tus datos.
#
# Página oficial: https://matplotlib.org

# %%
import matplotlib.pyplot as plt

# Datos de ventas mensuales
meses = ['Enero', 'Febrero', 'Marzo', 'Abril']
ventas = [120, 150, 180, 145]

# Crear un gráfico de líneas
plt.figure(figsize=(8, 4))
plt.plot(meses, ventas, marker='o')
plt.title('Ventas Mensuales')
plt.xlabel('Mes')
plt.ylabel('Unidades Vendidas')
plt.grid(True)
plt.show()

# %% [markdown]
# ### **Seaborn ✨**
# <p align="center">
# <img src="https://seaborn.pydata.org/_images/logo-mark-lightbg.svg" alt="Logo de Seaborn" width="200">
# </p>
#
# Es una librería que trabaja sobre Matplotlib para hacer gráficos estadísticos más bonitos y con menos código. Es como un kit de diseño que embellece los gráficos básicos.
#
# Página oficial: https://seaborn.pydata.org

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Datos de ejemplo
productos = ['Tornillo A', 'Tuerca B', 'Clavo C']
cantidades = [450, 600, 800]

# Crear un gráfico de barras con un estilo mejorado
plt.figure(figsize=(8, 5))
sns.barplot(x=productos, y=cantidades, palette='viridis')
plt.title('Cantidad Total Producida')
plt.show()
# Out:
# /tmp/ipython-input-1560189606.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=productos, y=cantidades, palette='viridis')

# %% [markdown]
# ### **Statsmodels 📈**
# <p align="center">
# <img src="https://avatars.githubusercontent.com/u/4971254?s=280&v=4" alt="Logo de Statsmodels" width="200">
# </p>
#
# Es un laboratorio de estadística. Se usa para aplicar modelos estadísticos más avanzados, como las regresiones lineales, y realizar pruebas de hipótesis.
# Página oficial: www.statsmodels.org

# %%
import statsmodels.api as sm
import numpy as np

# Datos: Gasto en publicidad (X) y Ventas (y)
gasto_publicidad = np.array([100, 150, 200, 250, 300])
ventas = np.array([500, 600, 650, 780, 850])

# Preparar los datos para el modelo
X = sm.add_constant(gasto_publicidad)

# Crear y ajustar el modelo de regresión lineal
modelo = sm.OLS(ventas, X).fit()

# Imprimir el resumen con los resultados estadísticos
print(modelo.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.986
# Model:                            OLS   Adj. R-squared:                  0.982
# Method:                 Least Squares   F-statistic:                     215.1
# Date:                Fri, 22 Aug 2025   Prob (F-statistic):           0.000687
# Time:                        04:44:08   Log-Likelihood:                -20.533
# No. Observations:                   5   AIC:                             45.07
# Df Residuals:                       3   BIC:                             44.28
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        324.0000     25.456     12.728      0.001     242.988     405.012
# ...

# %% [markdown]
# ## **Notación Big-O y orden de rapidez**
#
# La notación Big-O describe cómo crece el tiempo de ejecución (o uso de memoria) de un algoritmo cuando aumenta el tamaño de entrada
# 𝑛
# n.
# En general, mientras más lento crece la función, más rápido será el algoritmo para entradas grandes.
#
# Orden común de complejidades (de más rápida a más lenta):
#
# O(1) – Tiempo constante: no importa el tamaño de entrada (ej. acceso a un elemento en una lista).
#
# O(log n) – Logarítmica: crece muy lentamente (ej. búsqueda binaria).
#
# O(n) – Lineal: el tiempo crece proporcionalmente al tamaño (ej. recorrer una lista).
#
# O(n log n) – Lineal-logarítmica: típico de algoritmos de ordenamiento eficientes (ej. mergesort).
#
# O(n²) – Cuadrática: se vuelve lenta con listas grandes (ej. burbuja, inserción simple).
#
# O(2ⁿ) – Exponencial: se vuelve impráctica muy rápido (ej. fuerza bruta en problemas combinatorios).
#
# O(n!) – Factorial: extremadamente lenta incluso para valores pequeños (ej. permutaciones completas).

# %%
# Big-O demo con 7 complejidades y animación simple en Colab/Jupyter
# Reglas cumplidas: matplotlib, una sola gráfica, sin estilos/colores específicos.

import time
import math
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output, display

# --------- Funciones representativas ---------
def op_constante(n):
    # O(1): hace trabajo constante, independiente de n
    a = 42
    a += 1
    a *= 2
    return a

def op_log(n):
    # O(log n): duplica hasta pasar n
    x = 1
    while x < n:
        x *= 2

def op_lineal(n):
    # O(n): recorre n pasos
    for _ in range(n):
        pass

def op_nlogn(n):
    # O(n log n): n veces un trabajo logarítmico
    for _ in range(n):
        x = 1
        while x < n:
            x *= 2

def op_cuadratica(n):
    # O(n^2): dos bucles anidados
    for _ in range(n):
        for _ in range(n):
            pass

def op_exponencial(n):
    # O(2^n): simular 2**n "unidades de trabajo"
    # n pequeños/medianos para no bloquear
    for _ in range(2 ** n):
        pass

def op_factorial(n):
    # O(n!): simular n! "unidades de trabajo" (n muy pequeño)
    total = math.factorial(n)
    for _ in range(total):
        pass

# --------- Configuración de tamaños ---------
# Elegidos para que la animación sea perceptible pero breve
experimentos = [
    ("O(1)", op_constante, [10, 10**3, 10**6, 10**9]),
    ("O(log n)", op_log, [10**3, 10**4, 10**5, 10**6, 10**7]),
    ("O(n)", op_lineal, [2_000, 8_000, 20_000, 40_000, 80_000]),
    ("O(n log n)", op_nlogn, [300, 800, 1_600, 3_200, 6_400]),
    ("O(n^2)", op_cuadratica, [60, 100, 140, 180, 220]),
    ("O(2^n)", op_exponencial, [12, 14, 16, 18, 20, 22]),     # 2^22 ≈ 4.2M
    ("O(n!)", op_factorial, [7, 8, 9, 10])                    # 10! ≈ 3.6M
]

# --------- Estructuras para resultados ---------
resultados = {nombre: {"n": [], "t": []} for nombre, _, _ in experimentos}

# --------- Crear la figura (una sola) ---------
fig, ax = plt.subplots(figsize=(8, 5))
ax.set_title("Crecimiento temporal (Big-O) — 7 complejidades (animado)")
ax.set_xlabel("Tamaño de entrada n")
ax.set_ylabel("Tiempo (segundos)")
ax.set_xscale("log")
ax.set_yscale("log")
ax.grid(True)
plt.tight_layout()

# --------- Animación paso a paso ---------
for nombre, fn, ns in experimentos:
    for n in ns:
        t0 = time.perf_counter()
        fn(n)
        t1 = time.perf_counter()
        dt = t1 - t0

        resultados[nombre]["n"].append(n)
        resultados[nombre]["t"].append(dt)

        # Redibujar
        clear_output(wait=True)
        ax.cla()
        ax.set_title("Crecimiento temporal (Big-O) — 7 complejidades (animado)")
        ax.set_xlabel("Tamaño de entrada n")
        ax.set_ylabel("Tiempo (segundos)")
        ax.set_xscale("log")
        ax.set_yscale("log")
        ax.grid(True)

        # Dibujar cada serie disponible
        for serie_nombre, data in resultados.items():
            if data["n"]:
                ax.plot(data["n"], data["t"], marker="o", label=serie_nombre)

        ax.legend(loc="best")
        ax.set_ylim(bottom=1e-6)

        display(fig)
        print(f"Registrado {nombre} con n={n} → {dt:.6f} s")

        # Pausa corta para visualizar la progresión
        time.sleep(0.35)

# Nota: si alguna serie tarda demasiado en tu equipo, reduce los tamaños de 'n' correspondientes.
# Out:
# Registrado O(n!) con n=10 → 0.056154 s

# %% [markdown]
# ## **Cargar datos con pandas**
#
# En esta sección encontraras, como cargar un archivo .csv y realizar una exploración inicial, además de practicar el slicing (filas/columnas) y conteo de valores faltantes.

# %% [markdown]
# ### **Subir CSV desde tu equipo**
#
# Este código te permite cargar un archivo CSV directamente desde tu computadora a Google Colab.
#
# Al ejecutar la celda, aparecerá un botón para que selecciones el archivo que quieres subir. Una vez cargado, el código lo convierte automáticamente en una tabla de Pandas (DataFrame) y muestra sus primeras filas para que puedas confirmar que se leyó correctamente.

# %%
from io import BytesIO
import pandas as pd
try:
    from google.colab import files
    uploaded = files.upload()
    if len(uploaded):
        fname, fbytes = next(iter(uploaded.items()))
        da = pd.read_csv(BytesIO(fbytes))
        print("Archivo cargado:", fname, "| shape:", da.shape)
        display(da.head())
except Exception as e:
    print("Si no estás en Colab o prefieres otra opción, usa la Opción B/C/D. Detalle:", e)
# Out:
#      <input type="file" id="files-6940f2b6-6724-43e6-844b-93662623f545" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6940f2b6-6724-43e6-844b-93662623f545">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### **Subir CSV desde una URL**
#
# Esta opción carga un archivo CSV directamente desde una URL de internet.
#
# Simplemente necesitas la dirección web que apunte al archivo .csv en formato crudo (raw). La función pd.read_csv() de Pandas es lo suficientemente inteligente como para descargar y leer los datos directamente desde el enlace.

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv"
# La base de datos la vamos a llamar dw (data frame wine)
dw = pd.read_csv(url, sep=';')
display(dw.head())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# ### **Subir CSV desde Drive**
#
# Esta es la opción más recomendada para trabajar con tus propios archivos de forma permanente.
#
# El código primero conecta ("monta") tu Google Drive al entorno de Colab, pidiéndote autorización. Una vez conectado, puedes leer cualquier archivo CSV que tengas guardado en tu Drive, simplemente indicando su ruta como si fuera una carpeta local.

# %%
#Descomente las próximas líneas e indique cual podrá ser el error
#from google.colab import drive
#drive.mount('/content/drive')
#da = pd.read_csv('/content/drive/MiCarpeta/datos.csv')
#da.head()

# %% [markdown]
# ### **Construir un data frame (CSV) de ejemplo**
#
# En esta sección, vamos a "inventar" un conjunto de datos para la clase usando las librerías numpy y pandas. A esta tabla la llamaremos da.
#
# El código crea una tabla (DataFrame) con 250 filas y le añade columnas con datos generados aleatoriamente que simulan una encuesta de salud. Además, calcula el Índice de Masa Corporal (IMC) y agrega intencionalmente algunos valores vacíos para practicar cómo se manejan los datos incompletos en un escenario real.
#
# Cada variable (columna) representa lo siguiente:
#
# *  SEQN: Un identificador único para cada persona en el estudio.
#
# *  RIAGENDR: Género, representado con números (1 y 2). Es una variable categórica.
#
# *  RIDAGEYR: Edad de la persona en años.
#
# *  BMXWT: Peso en kilogramos.
#
# *  BMXHT: Altura en centímetros.
#
# *  BMXBMI: Índice de Masa Corporal (IMC), que se calcula a partir del peso y la altura.
#
# *  PAIS: País de origen de la persona. Esta es otra variable categórica que hemos añadido.

# %%
#Cargada una vez la libreria, no se debe volver a cargar de nuevo.
import numpy as np
import pandas as pd

# Fijar una semilla para que los resultados aleatorios sean siempre los mismos
np.random.seed(42)

# Número de filas que tendrá nuestra tabla
n = 250

# Crear el DataFrame
da = pd.DataFrame({
    "SEQN": np.arange(1, n+1),
    "RIAGENDR": np.random.choice([1, 2], size=n, p=[0.5, 0.5]), # 1: Masculino, 2: Femenino
    "RIDAGEYR": np.random.randint(18, 80, size=n),
    "BMXWT": np.round(np.random.normal(70, 12, size=n), 1), # Peso en kg
    "BMXHT": np.round(np.random.normal(168, 10, size=n), 1), # Altura en cm
    "PAIS": np.random.choice(["Colombia", "Mexico", "Argentina"], size=n, p=[0.6, 0.2, 0.2]) # Variable categórica de texto
})

# Calcular el IMC y añadirlo como una nueva columna
da["BMXBMI"] = np.round(da["BMXWT"] / (da["BMXHT"]/100)**2, 1)

# Simular datos faltantes: seleccionar 10 filas al azar y poner NaN en la columna de peso
da.loc[np.random.choice(da.index, size=10, replace=False), "BMXWT"] = np.nan

# Mostrar las primeras 5 filas de nuestra tabla para revisarla
da.head()
# Out:
#    SEQN  RIAGENDR  RIDAGEYR  BMXWT  BMXHT       PAIS  BMXBMI
# 0     1         1        78   81.4  150.3     Mexico    36.0
# 1     2         2        38   87.4  157.7  Argentina    35.1
# 2     3         2        49   74.3  169.7     Mexico    25.8
# 3     4         2        40   77.0  168.9   Colombia    27.0
# 4     5         1        50   62.4  172.9   Colombia    20.9

# %% [markdown]
# ## **Datos de ejemplo**
#
# Una vez que tenemos nuestros datos, el primer paso es siempre hacer una exploración inicial para entender con qué estamos trabajando. Este proceso es como un chequeo médico rápido para nuestro conjunto de datos.
#
# Usaremos comandos sencillos de Pandas para responder preguntas clave:
#
# * ¿Qué tan grande es mi tabla? (.shape)
#
# * ¿Qué información contiene? (.columns)
#
# * ¿Qué tipo de datos hay en cada columna? (.dtypes)
#
# * ¿Cómo se ven las primeras filas? (.head())
#
# * ¿Cuáles son las estadísticas básicas de mis datos? (.describe())

# %%
# --- Exploración Inicial del DataFrame ---

# 1. Muestra las dimensiones de la tabla (filas, columnas)
print("Dimensiones de la tabla (shape):", da.shape)

# 2. Muestra una lista con los nombres de todas las columnas
print("\nNombres de las columnas (columns):", list(da.columns))

# 3. Muestra el tipo de dato de cada columna (ej. número entero, texto, decimal)
print("\nTipos de datos por columna (dtypes):")
display(da.dtypes)

# 4. Muestra una vista previa de las primeras 5 filas de la tabla
print("\nPrimeras 5 filas (head):")
display(da.head())

# 5. Calcula estadísticas descriptivas para todas las columnas (incluyendo las de texto)
print("\nResumen estadístico (describe):")
display(da.describe(include='all'))
# Out:
# Dimensiones de la tabla (shape): (250, 7)
#
# Nombres de las columnas (columns): ['SEQN', 'RIAGENDR', 'RIDAGEYR', 'BMXWT', 'BMXHT', 'PAIS', 'BMXBMI']
#
# Tipos de datos por columna (dtypes):
# SEQN          int64
# RIAGENDR      int64
# RIDAGEYR      int64
# BMXWT       float64
# BMXHT       float64
# PAIS         object
# BMXBMI      float64
# dtype: object
# Primeras 5 filas (head):
#    SEQN  RIAGENDR  RIDAGEYR  BMXWT  BMXHT       PAIS  BMXBMI
# 0     1         1        78   81.4  150.3     Mexico    36.0
# 1     2         2        38   87.4  157.7  Argentina    35.1
# 2     3         2        49   74.3  169.7     Mexico    25.8
# 3     4         2        40   77.0  168.9   Colombia    27.0
# 4     5         1        50   62.4  172.9   Colombia    20.9
# Resumen estadístico (describe):
#               SEQN    RIAGENDR    RIDAGEYR       BMXWT      BMXHT      PAIS  \
# count   250.000000  250.000000  250.000000  240.000000  250.00000       250
# ...

# %% [markdown]
# ### **Slicing: Seleccionar Filas y Columnas**
#
# "Slicing" (o rebanar) es la técnica que usamos para seleccionar pedazos específicos de nuestra tabla. Podemos querer ver solo una columna (como la edad de todos los participantes) o una fila completa (todos los datos de una persona específica).
#
# Pandas nos ofrece varias formas de hacerlo, siendo las más comunes .loc (para seleccionar por nombre) e .iloc (para seleccionar por número de posición).
#
# * **Seleccionar una Columna**
# Hay múltiples maneras de seleccionar una sola columna. Aunque la sintaxis varía, todas las opciones que se muestran a continuación logran exactamente lo mismo: aislar la columna RIDAGEYR (edad).
#
# * **Seleccionar una Fila**
# Para seleccionar una fila por su posición, usamos .iloc. Es importante recordar que en Python se empieza a contar desde 0, por lo que .iloc[3] en realidad selecciona la cuarta fila de la tabla.

# %%
# --- Formas de seleccionar la columna de edad (RIDAGEYR) ---

# Opción 1: Usando corchetes y el nombre de la columna (la más común)
w = da["RIDAGEYR"]

# Opción 2: Usando .loc para seleccionar por nombre
x = da.loc[:, "RIDAGEYR"] # El ":" significa "todas las filas"

# Opción 3: Usando un punto (solo funciona si el nombre no tiene espacios)
y = da.RIDAGEYR

# Opción 4: Usando .iloc para seleccionar por número de columna
z = da.iloc[:, da.columns.get_loc("RIDAGEYR")]

# Verificamos que todas las formas dieron el mismo resultado
print("Max RIDAGEYR (cuatro formas):", w.max(), x.max(), y.max(), z.max())


# --- Seleccionar la cuarta fila de la tabla (índice 3) ---
fila4 = da.iloc[3, :] # El ":" al final significa "todas las columnas"
display(fila4)
# Out:
# Max RIDAGEYR (cuatro formas): 79 79 79 79
# SEQN               4
# RIAGENDR           2
# RIDAGEYR          40
# BMXWT           77.0
# BMXHT          168.9
# PAIS        Colombia
# BMXBMI          27.0
# Name: 3, dtype: object

# %% [markdown]
# ### **Manejo de Datos Faltantes (NaN)**
#
# En los conjuntos de datos del mundo real, es muy común que falte información. Pandas representa estos vacíos con un valor especial llamado NaN (Not a Number). Antes de hacer cualquier análisis, es crucial identificar cuántos datos faltantes tenemos y decidir qué hacer con ellos.
#
#
# **¿Qué hacer con los datos faltantes?**
# Una vez identificados, existen varias estrategias comunes para manejarlos. La elección depende del problema y de la cantidad de datos que falten.
#
# **Eliminar las filas:** Si tienes muy pocos datos faltantes en un conjunto de datos muy grande, la solución más simple es eliminar las filas completas que contienen un NaN.
#
#   Ventaja: Es rápido y fácil.
#
#   Desventaja: Pierdes la información de las otras columnas de esa misma fila.
#
# **Rellenar (imputar) los valores:** Consiste en reemplazar el NaN con un valor calculado a partir del resto de la columna.
#
# * **Opción A (para números):** Rellenar con el promedio (media) o la mediana de la columna. La mediana suele ser mejor si hay valores atípicos.
#
# * **Opción B (para categorías):** Rellenar con la moda (el valor que más se repite).
#
#   Ventaja: No pierdes filas enteras de datos.
#
#   Desventaja: Puede introducir un pequeño sesgo en los datos.
#
# **Dejarlos como están**: Algunos modelos de machine learning son capaces de manejar los valores faltantes por sí mismos, aunque no es lo más común.
#
#
#
#
# El siguiente código cuenta cuántos valores faltantes (NaN) y no faltantes hay en la columna de peso (BMXWT).

# %%
faltantes_bmxwt = pd.isnull(da["BMXWT"]).sum()
no_faltantes_bmxwt = pd.notnull(da["BMXWT"]).sum()

print("BMXWT → faltantes:", faltantes_bmxwt, "| no faltantes:", no_faltantes_bmxwt)
# Out:
# BMXWT → faltantes: 10 | no faltantes: 240

# %% [markdown]
# ### **Visualizar una Variable Numérica (Histograma)**
#
# Para las variables numéricas como la edad (RIDAGEYR), el histograma es el gráfico ideal. Agrupa los números en "cajones" o intervalos llamados bins y nos muestra cuántos datos caen en cada uno.
#
# Para decidir cuántos bins usar, una regla clásica es la Regla de Sturges, que busca un balance para que el gráfico sea legible. La fórmula es k = 1 + 3.322 * log10(n), donde n es el número de datos. Existen otras reglas como la de Scott o Freedman-Diaconis que también son muy útiles.

# %%
# --- Histograma para la Edad (RIDAGEYR) ---

# 1. Calcular el número de bins usando la Regla de Sturges
n = len(da)
k = int(1 + 3.322 * np.log10(n))
print(f"Número de datos (n): {n}")
print(f"Bins sugeridos por Sturges (k): {k}")


# 2. Crear el histograma
plt.figure(figsize=(10, 5))
plt.hist(da["RIDAGEYR"].dropna(), bins=k, color='skyblue', edgecolor='black')

# Añadir títulos y etiquetas
plt.title('Distribución de Edades (RIDAGEYR)')
plt.xlabel('Edad (años)')
plt.ylabel('Frecuencia (cantidad de personas)')
plt.grid(axis='y', alpha=0.75)

# Mostrar el gráfico
plt.show()
# Out:
# Número de datos (n): 250
# Bins sugeridos por Sturges (k): 8

# %% [markdown]
# ### **Visualizar una Variable Categórica (Gráfico de Barras)**
# Para variables categóricas como el país (PAIS), donde los datos son etiquetas de texto, el gráfico de barras es perfecto. Simplemente cuenta cuántas veces aparece cada categoría y muestra el total con una barra.

# %%
# --- Gráfico de Barras para el País (PAIS) ---

# 1. Contar la frecuencia de cada categoría
conteo_paises = da['PAIS'].value_counts()
print("Conteo por país:")
print(conteo_paises)


# 2. Crear el gráfico de barras
plt.figure(figsize=(8, 5))
plt.bar(conteo_paises.index, conteo_paises.values, color=['#0033A0', '#FCD116', '#CE1126'])

# Añadir títulos y etiquetas
plt.title('Distribución de Personas por País')
plt.xlabel('País')
plt.ylabel('Cantidad de Personas')

# Mostrar el gráfico
plt.show()
# Out:
# Conteo por país:
# PAIS
# Colombia     138
# Mexico        59
# Argentina     53
# Name: count, dtype: int64

# %% [markdown]
# # **TALLER 1 (fecha de entrega 22 de Agosto hasta las 11:59 P.M)**
# **Celdas de código sin ejecutar en su totalidad no se califican.**

# %% [markdown]
# ## **Instrucciones generales (léelas antes de empezar)**
# * No modifiques las celdas de enunciado.
# * Responde únicamente debajo de cada pregunta, agregando celdas nuevas de Markdown (para explicar/justificar) y/o Código (para ejecutar).
# * Justifica muy bien cada respuesta. El código sin explicación no es suficiente.
#
# * El archivo final debe llamarse siguiendo el patrón:
#   ApellidoNombre_ApellidoNombre_ApellidoNombre.ipynb
#   Ejemplo: DuarteCarlos_GarzonJuana_RestrepoTomas.ipynb
#
# Los tres o dos integrantes de cada grupo deben subir el archivo al repositorio de GitHub que cada uno creo de manera individual, al final del este notebook en la sección de “Integrantes y enlaces”, escribe los nombres y los enlaces a los repositorios personales de cada integrante.
#
#
# Ejemplo de enlace final:
#
# Integrante 1: Fredy Orjuela
#
# Enlace GitHub 1: https://github.com/faorjuelal/SAPP---IIND---005786
#
# **Esto es muy importante ya que se puede elegir cualqueir notebbok al azar de los integrantes.**

# %% [markdown]
# ## **Preguntas**
#
# 1. **Crear cuenta en GitHub:** Regístrate en https://github.com con tu correo institucional. Elige un nombre de usuario profesional y verifica tu correo.
#
# 2. **Crear repositorio en GitHub:** Crea un repositorio público (activa Add a README file). Copia y guarda el enlace del repositorio. Describe los pasos realizados.
#
# 3. **Subir un notebook desde Colab a GitHub:** Explica y realiza el proceso de Archivo → Guardar una copia en GitHub (autorización, selección de repo, mensaje de commit).
#
# 4. **Actualizar un notebook ya guardado en GitHub:** ¿Cómo guardar cambios sobre el mismo archivo en lugar de crear uno nuevo? Explica el flujo con un mensaje de commit adecuado.
#
# 5. **TPU vs GPU en Google Colab:** ¿Qué diferencia hay y cuándo se recomienda usar cada una?
#
# 6. **Usando la base dw (wine):** reporta shape, columns, dtypes, .head() y .describe().
#
# 7. **En dw:** selecciona dos variables numéricas y calcula para cada una: media, mediana, desviación estándar y cuantiles (25%, 50%, 75%).
#
# 8. **Tabla de frecuencias:** muestra cómo construir una tabla de frecuencias para una variable categórica en Pandas (value_counts()) y cómo convertirla en DataFrame.
#
# 9. **Valores faltantes en dw:** identifica las columnas con valores faltantes y muestra el conteo por columna
#
# 10. **Subconjunto y estadísticas:** en dw, toma las columnas "free sulfur dioxide" y "density", crea un nuevo DataFrame con ellas y reporta sus estadísticas descriptivas.

# %% [markdown]
# # **SOLUCIÓN TALLER 1**
# Respuestas (agrega tus celdas debajo de cada pregunta)
# Importante: No borres ni edites las celdas de enunciado. Añade tus respuestas debajo de cada pregunta, para ello copia cada pregunta y responde si requieres texto agrega +Texto, si requieres código, agrega más código.
#
# Integrante 1: Fabian Aguirre
#
# Enlace Github 1: https://github.com/fabianaguirres/sistemas-avanzados-de-produccion
#
# Integrante 2: Jonathan Garcia
#
# Enlace Github 2: https://github.com/jonathandgarciaro-lab/sistemas-avanzados-de-produccion
#
# Integrante 3: Mercy diaz
#
# Enlace Github 3: https://github.com/mercykdiazv/sistemas-avanzados-de-produccion
#
#
# Integrante 4: Daniel León
#
# Enlace Github 4: https://github.com/DanielFLeonC/sistemas-avanzados-de-produccion

# %% [markdown]
# # **RESPUESTA PUNTO 1, 2 Y 3**
#
# - https://github.com/DanielFLeonC/sistemas-avanzados-de-produccion/blob/main/aguirre_fabian_leon_daniel_garcia_jonathan_diaz_mercy.ipynb
#
# - https://github.com/jonathandgarciaro-lab/sistemas-avanzados-de-produccion/blob/main/aguirre_fabian_leon_daniel_garcia_jonathan_diaz_mercy.ipynb
#
# - https://github.com/fabianaguirres/sistemas-avanzados-de-produccion/blob/main/aguirre_fabian_leon_daniel_garcia_jonathan_diaz_mercy.ipynb
#
# - https://github.com/mercykdiazv/sistemas-avanzados-de-produccion/blob/main/aguirre_fabian_leon_daniel_garcia_jonathan_diaz_mercy.ipynb

# %% [markdown]
# # 📘 Guía: Guardar tu Notebook en GitHub desde Google Colab
#
# ---
#
# ## PASO 1: Abrir tu cuenta en GitHub 🚀
#
# GitHub es como una red social para guardar y compartir proyectos de código.
#
# 1. **Ve a la página de registro:** Abre tu navegador y visita 👉 [github.com](https://github.com/)
# 2. **Regístrate:** Haz clic en el botón **"Sign up"**.
# 3. **Usa tu cuenta de Google (Recomendado):** Para que sea más rápido, elige la opción **"Continue with Google"** y selecciona tu cuenta institucional `@ecci.edu.co`.
# 4. **Sigue las instrucciones:** GitHub te hará un par de preguntas para configurar tu perfil. ¡No te tomará más de un minuto!
# 5. **Instala la App:** Busca **GitHub** en la *Play Store (Android)* o *App Store (iOS)* e instálala en tu celular para gestionar tus proyectos desde cualquier lugar.
#
# ➡️ **Video de ayuda (4 min):** *Cómo crear una cuenta en GitHub*
#
# ---
#
# ## PASO 2: Crear tu primer archivo (README.md) 📝
#
# Un archivo `README.md` es la carta de presentación de tu proyecto. Es lo primero que la gente ve.
#
# 1. **Crea un repositorio:** Haz clic en el botón **"+"** en la esquina superior derecha y selecciona **"New repository"**.
# 2. **Dale un nombre:** Ponle un nombre corto y descriptivo (ej. *Mi-Primera-Actividad*) y déjalo con perfil **público**.
# 3. **Inicia con un README:** Marca la casilla que dice **"Add a README file"**.
# 4. **Crea el repositorio:** Haz clic en el botón verde **"Create repository"**.
#
# ➡️ **Video de ayuda (3 min):** *Crear un repositorio y archivo README*
#
# ---
#
# ## PASO 3: Guardar tu Notebook de Google Colab en GitHub 🔗
#
# Ahora vamos a conectar **Google Colab** con **GitHub** para guardar tu trabajo directamente en tu repositorio.
# Olvídate de descargar y subir archivos manualmente.
#
# 1. **Abre tu Notebook en Colab:**
#    - Ve a tu Google Drive y busca tu archivo de trabajo (ej: `Apellido_Nombre.ipynb`).
#    - Haz clic derecho y selecciona: **Abrir con > Google Colaboratory**.
#
# 2. **Inicia el proceso de guardado:**
#    - En Colab, ve al menú superior y haz clic en **Archivo**.
#    - Selecciona la opción **"Guardar una copia en GitHub"**.
#
# 3. **Autoriza la conexión (solo la primera vez):**
#    - Aparecerá una ventana emergente pidiéndote autorización.
#    - Haz clic en **"Autorizar a Google Colab"** y sigue las instrucciones.
#
# 4. **Configura dónde guardarlo:**
#    - **Repositorio:** Selecciona el repositorio que creaste en el PASO 2.
#    - **Mensaje de commit:** Escribe un comentario corto, ej: `"Versión final de mi actividad"` o `"Entrega del taller 1"`.
#    - Asegúrate de marcar la casilla **"Incluir un enlace a Colaboratory"**.
#
# 5. **Confirma y listo:**
#    - Haz clic en **Aceptar**.
#    - Espera unos segundos y tu Notebook se guardará directamente en GitHub ✅.
#
# ---

# %% [markdown]
# # **RESPUESTA PUNTO 4**
#
# Para actualizar un archivo existente en un repositorio de GitHub sin crear un nuevo archivo, debes seguir estos pasos:
#
# Flujo de trabajo:
#
# 1. Clonar el repositorio
# 2. Navegar al directorio del repositorio: Accede al directorio de tu repositorio.
# 3. Actualizar el archivo (notebook en este caso):
# Modifica el archivo que deseas actualizar, como un archivo .ipynb. Abre el archivo con tu editor de texto o herramienta de notebooks (por ejemplo, Jupyter Notebook) y realiza los cambios que necesitas.
# 4. Verificar el estado de los archivos:
# Después de realizar los cambios, verifica el estado de los archivos para ver cuáles han sido modificados.
# 5. Añadir los cambios al área de preparación (staging area):
# Agrega los cambios realizados al área de preparación con.
# 6. Realizar un commit:
# Ahora, realiza un commit de tus cambios con un mensaje adecuado. Es importante que el mensaje sea descriptivo y explique qué cambios realizaste. Un mensaje típico de commit podría ser.
# 7. Hacer un push de los cambios a GitHub:
# Luego de hacer el commit, envía los cambios a tu repositorio en GitHub con.
# 8. Verificar en GitHub:
# Una vez que el push se haya completado, puedes verificar en GitHub para asegurarte de que el archivo ha sido actualizado correctamente.

# %% [markdown]
# # **RESPUESTA PUNTO 5**
#
# En Google Colab, las GPU (tarjetas gráficas) son más flexibles y fáciles de usar, ideales para la mayoría de proyectos en PyTorch y TensorFlow de tamaño pequeño o mediano, ya que aceleran operaciones de álgebra lineal como convoluciones y multiplicaciones de matrices; mientras que las TPU (unidades de procesamiento tensorial de Google) son chips especializados en deep learning, mucho más rápidas y eficientes para entrenar modelos grandes en TensorFlow o JAX, aunque requieren adaptar el código y no son tan compatibles con PyTorch; en resumen, usa GPU para prototipos y proyectos generales y TPU cuando trabajes en TensorFlow con modelos de gran escala que demanden entrenamiento distribuido y alto rendimiento.

# %% [markdown]
# # **RESPUESTA PUNTO 6**

# %%
# --- Exploración Inicial del DataFrame ---

# 1. Muestra las dimensiones de la tabla (filas, columnas)
print("Dimensiones de la tabla (shape):", dw.shape)

# 2. Muestra una lista con los nombres de todas las columnas
print("\nNombres de las columnas (columns):", list(dw.columns))

# 3. Muestra el tipo de dato de cada columna (ej. número entero, texto, decimal)
print("\nTipos de datos por columna (dtypes):")
display(dw.dtypes)

# 4. Muestra una vista previa de las primeras 5 filas de la tabla
print("\nPrimeras 5 filas (head):")
display(dw.head())

# 5. Calcula estadísticas descriptivas para todas las columnas (incluyendo las de texto)
print("\nResumen estadístico (describe):")
display(dw.describe(include='all'))
# Out:
# Dimensiones de la tabla (shape): (1599, 1)
#
# Nombres de las columnas (columns): ['fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"']
#
# Tipos de datos por columna (dtypes):
# fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"    object
# dtype: object
# Primeras 5 filas (head):
#   fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0   7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# 1   7.8;0.88;0;2.6;0.098;25;67;0.9968;3.2;0.68;9.8;5
# 2  7.8;0.76;0.04;2.3;0.092;15;54;0.997;3.26;0.65;...
# 3  11.2;0.28;0.56;1.9;0.075;17;60;0.998;3.16;0.58...
# 4   7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# ...

# %% [markdown]
# # EXPLICACION:
#
# Este código realiza una exploración inicial del DataFrame dw, mostrando su tamaño (filas y columnas), los nombres y tipos de cada variable, una vista previa de las primeras filas y un resumen estadístico general. En conjunto, permite entender la estructura básica y las características principales de los datos antes de analizarlos.

# %% [markdown]
# # **RESPUESTA PUNTO 7**

# %%
# ============================================================
# 📊 Estadísticos descriptivos de dos variables numéricas
# ============================================================

# 🔹 Seleccionamos dos columnas numéricas del DataFrame dw
var1 = "fixed acidity"
var2 = "alcohol"

# Guardamos en una lista para iterar
variables = [var1, var2]

# Iteramos sobre cada variable seleccionada
for var in variables:
    print(f"\n📌 Análisis de la variable: {var}")
    print("-" * 60)

    # Media
    print(f"🔹 Media: {dw[var].mean():.2f}")

    # Mediana
    print(f"🔹 Mediana: {dw[var].median():.2f}")

    # Desviación estándar
    print(f"🔹 Desviación estándar: {dw[var].std():.2f}")

    # Cuantiles
    print("🔹 Cuantiles (25%, 50%, 75%):")
    print(dw[var].quantile([0.25, 0.5, 0.75]))
    print("-" * 60)
# Out:
# 📌 Análisis de la variable: fixed acidity
# ------------------------------------------------------------
# 🔹 Media: 8.32
# 🔹 Mediana: 7.90
# 🔹 Desviación estándar: 1.74
# 🔹 Cuantiles (25%, 50%, 75%):
# 0.25    7.1
# 0.50    7.9
# 0.75    9.2
# Name: fixed acidity, dtype: float64
# ------------------------------------------------------------
#
# 📌 Análisis de la variable: alcohol
# ------------------------------------------------------------
# 🔹 Media: 10.42
# 🔹 Mediana: 10.20
# 🔹 Desviación estándar: 1.07
# 🔹 Cuantiles (25%, 50%, 75%):
# 0.25     9.5
# 0.50    10.2
# 0.75    11.1
# Name: alcohol, dtype: float64
# ------------------------------------------------------------

# %% [markdown]
# # EXPLICACION:
#
# Ese código selecciona dos variables numéricas del DataFrame dw (fixed acidity y alcohol) y, de manera iterativa, calcula sus principales medidas estadísticas. Para cada variable muestra la media, que indica el promedio de los valores; la mediana, que representa el valor central de la distribución; la desviación estándar, que mide la dispersión de los datos; y los cuantiles (25%, 50%, 75%), que permiten entender cómo se distribuyen los valores en distintos tramos. En conjunto, este análisis ofrece una visión clara del comportamiento y la variabilidad de esas dos características del vino.

# %% [markdown]
# # **RESPUESTA PUNTO 8**

# %%
# ============================================================
# 📊 Gráfico de Barras para la variable "quality"
# ============================================================

import matplotlib.pyplot as plt

# 1. Contar la frecuencia de cada categoría en "quality"
conteo_quality = dw['quality'].value_counts().sort_index()
print("Conteo por calidad del vino:")
print(conteo_quality)

# 2. Crear el gráfico de barras
plt.figure(figsize=(8, 5))
plt.bar(conteo_quality.index, conteo_quality.values, color='#8B0000')

# Añadir títulos y etiquetas
plt.title('Distribución de Vinos por Calidad', fontsize=14)
plt.xlabel('Calidad del Vino (score)', fontsize=12)
plt.ylabel('Cantidad de Vinos', fontsize=12)

# Mostrar el gráfico
plt.show()
# Out:
# Conteo por calidad del vino:
# quality
# 3     10
# 4     53
# 5    681
# 6    638
# 7    199
# 8     18
# Name: count, dtype: int64

# %% [markdown]
# # **EXPLICACION:**
#
# Ese código construye un gráfico de barras para la variable quality, que representa la calidad del vino en la base de datos.
#
# Primero, cuenta cuántos vinos hay en cada nivel de calidad usando value_counts(), y los ordena de menor a mayor con sort_index(). Después, con Matplotlib, crea un gráfico de barras donde el eje X muestra las calificaciones de calidad (scores) y el eje Y la cantidad de vinos que corresponden a cada una.
#
# Finalmente, se añaden títulos y etiquetas para que la visualización sea más clara. En resumen, este código permite ver de manera rápida cómo se distribuyen los vinos según su nivel de calidad.

# %% [markdown]
# # **RESPUESTA PUNTO 9**

# %%
# ============================================================
# 📊 Valores faltantes en dw
# ============================================================

# Calcular los valores faltantes por columna
faltantes = dw.isnull().sum()

# Filtrar únicamente las columnas que tienen faltantes
faltantes = faltantes[faltantes > 0]

# Mostrar resultado
print("🔎 Conteo de valores faltantes por columna en el DataFrame dw:")

# Si hay columnas con faltantes, mostrarlas
if not faltantes.empty:
    display(faltantes.to_frame(name="Valores faltantes"))
else:
    print("✅ No se encontraron valores faltantes en el DataFrame.")
# Out:
# 🔎 Conteo de valores faltantes por columna en el DataFrame dw:
# ✅ No se encontraron valores faltantes en el DataFrame.

# %% [markdown]
# # **EXPLICACION:**
#
# Ese código sirve para detectar si el DataFrame dw tiene valores faltantes (NaN) en alguna de sus columnas.
#
# Primero, usa isnull().sum() para contar cuántos valores faltan en cada columna. Luego, filtra y conserva solo las columnas donde efectivamente hay valores faltantes. Después, muestra los resultados:
#
# Si encuentra columnas con valores faltantes, las despliega junto con la cantidad de datos vacíos.
#
# Si no hay valores faltantes, imprime un mensaje indicando que el DataFrame está completo.
#
# En resumen, este código permite verificar rápidamente si existen datos incompletos y en qué columnas, lo cual es fundamental antes de realizar cualquier análisis.

# %% [markdown]
# # **RESPUESTA PUNTO 10**

# %%
# ============================================================
# 📊 Subconjunto y estadísticas descriptivas
# ============================================================

# 1. Crear un nuevo DataFrame solo con las columnas seleccionadas
sub_dw = dw[["free sulfur dioxide", "density"]]

# 2. Mostrar las primeras filas del subconjunto
print("🔎 Vista previa del subconjunto:")
display(sub_dw.head())

# 3. Calcular estadísticas descriptivas
print("📊 Estadísticas descriptivas de 'free sulfur dioxide' y 'density':")
display(sub_dw.describe())
# Out:
# 🔎 Vista previa del subconjunto:
#    free sulfur dioxide  density
# 0                 11.0   0.9978
# 1                 25.0   0.9968
# 2                 15.0   0.9970
# 3                 17.0   0.9980
# 4                 11.0   0.9978
# 📊 Estadísticas descriptivas de 'free sulfur dioxide' y 'density':
#        free sulfur dioxide      density
# count          1599.000000  1599.000000
# mean             15.874922     0.996747
# std              10.460157     0.001887
# min               1.000000     0.990070
# 25%               7.000000     0.995600
# 50%              14.000000     0.996750
# 75%              21.000000     0.997835
# max              72.000000     1.003690

# %% [markdown]
# # EXPLICACION:
#
# Este código tiene como objetivo enfocar el análisis en dos variables específicas del conjunto de datos del vino: “free sulfur dioxide” y “density”.
#
# Primero, se construye un subconjunto del DataFrame dw que contiene únicamente estas dos columnas, lo que permite trabajar de manera más clara y precisa con la información de interés. A continuación, se muestra una vista previa de las primeras filas de este subconjunto, facilitando una inspección rápida de cómo están organizados los datos.
#
# Finalmente, se calculan y presentan las estadísticas descriptivas de ambas variables, incluyendo medidas como el número de registros, la media, la desviación estándar, los valores mínimos y máximos, así como los cuantiles. Con esto, se obtiene una visión más profunda del comportamiento y distribución de estas variables, lo cual es útil para identificar tendencias, variabilidad y posibles valores atípicos dentro de los datos.
#
# > Agregar bloque entrecomillado

# %%
# ============================================================
# 📊 Subconjunto y estadísticas descriptivas personalizadas
# ============================================================

# 1. Crear un nuevo DataFrame solo con las columnas seleccionadas
sub_dw = dw[["free sulfur dioxide", "density"]]

# 2. Mostrar las primeras filas del subconjunto
print("🔎 Vista previa del subconjunto:")
display(sub_dw.head())

# 3. Estadísticas generales con describe()
print("📊 Estadísticas descriptivas generales:")
display(sub_dw.describe())

# 4. Estadísticas personalizadas
estadisticas = pd.DataFrame({
    "Media": sub_dw.mean(),
    "Mediana": sub_dw.median(),
    "Desviación estándar": sub_dw.std(),
    "Q1 (25%)": sub_dw.quantile(0.25),
    "Q2 (50%)": sub_dw.quantile(0.50),
    "Q3 (75%)": sub_dw.quantile(0.75)
})

print("📊 Tabla comparativa personalizada:")
display(estadisticas)
# Out:
# 🔎 Vista previa del subconjunto:
#    free sulfur dioxide  density
# 0                 11.0   0.9978
# 1                 25.0   0.9968
# 2                 15.0   0.9970
# 3                 17.0   0.9980
# 4                 11.0   0.9978
# 📊 Estadísticas descriptivas generales:
#        free sulfur dioxide      density
# count          1599.000000  1599.000000
# mean             15.874922     0.996747
# std              10.460157     0.001887
# min               1.000000     0.990070
# 25%               7.000000     0.995600
# 50%              14.000000     0.996750
# 75%              21.000000     0.997835
# max              72.000000     1.003690
# 📊 Tabla comparativa personalizada:
#                          Media   Mediana  Desviación estándar  Q1 (25%)  \
# free sulfur dioxide  15.874922  14.00000            10.460157    7.0000
# density               0.996747   0.99675             0.001887    0.9956
#
#                      Q2 (50%)   Q3 (75%)
# ...
